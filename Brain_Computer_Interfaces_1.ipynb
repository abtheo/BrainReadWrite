# %% [markdown]
# <a href="https://colab.research.google.com/github/abtheo/BrainReadWrite/blob/master/Brain_Computer_Interfaces_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brain Computer Interfaces 1
#
# ---
#
#
#
# In this notebook, we will perform offline analysis on the [BCI Competition III dataset II](http://www.bbci.de/competition/iii/#data_set_ii) from the Wadsworth Center in New York made available by Wolpaw, Schalk, and Krusienski. This dataset contains EEG data recorded while two participants operated a standard rows/columns $6 \times 6$ P300 matrix speller.

# %% [markdown]
# ### Learning goals
# After this assignment, you will have hand-on experience with
# * the BCI cycle as applied to the classic rows/columns P300 speller
# * applying a low-pass and high-pass filter and downsampling for preprocessing
# * using block-processing to work with epoched data
# * spatial filtering using CCA

# %% [markdown]
# ### Table of contents
#
# 1. [The dataset](#dataset)
#     1. [The stimulus paradigm](#stimulus)
#     2. [The EEG data](#eeg)
# 2. [Preprocessing](#preproc)
#     1. [Spectral filter](#spectralfilter)
#     2. [Downsampling](#downsampling)
#     3. [Trick for offline analysis](#trick)
# 3. [Data slicing](#slicing)
#     1. [Slicing to epochs](#epochs)
#     2. [Temporal response](#temporal)
#     3. [Spatial response](#spatial)
# 4. [Decoding the neural code](#decoding)
#     1. [Classifier calibration](#calibration)
#     2. [Epoch prediction](#ep)
#     3. [Epoch classification](#ec)
#     4. [Trial prediction](#tp)
#     5. [Trial classification](#tc)
#     6. [Decoding curves](#dc)
#     7. [Inspecting the classifier](#classifier)
# 5. [Extension: Canonical Correlation Analysis](#extension)
#     1. [The CCA](#cca)
#     2. [Classifier calibration](#calibration2)
#     2. [Epoch prediction](#ep2)
#     3. [Epoch classification](#ec2)
#     4. [Trial prediction](#tp2)
#     5. [Trial classification](#tc2)
#     6. [Decoding curves](#dc2)
#     7. [Inspecting the classifier](#classifier2)

# %%
# Some imports
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Ellipse, Polygon
from scipy.interpolate import griddata
from scipy.signal import periodogram, butter, filtfilt
from sklearn.cross_decomposition import CCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
import math

# %%
def topoplot(z, c, cbar=False):
    """
    Function to plot a topoplot given the values at each electrode `z` and the electrode position file `c` that 
    denotes the electrode positions in polar coordinates.
    
    Args:
        z (numpy.ndarray): array of electrode values
        c (str): txt file containing electrode position information
        cbar (bool): whether or not to add a colorbar (default: False)
    """
    
    # Read electrode positions
    with open(c) as fid:
        lines = fid.read().split("\n")
        xy = np.zeros((len(lines), 2))
        for i, line in enumerate(lines):
            __, t, r, __ = line.split("\t")
            t = (float(t) + 90) / 180 * np.pi
            r = float(r) * 2
            xy[i, :] = r*np.cos(t), r*np.sin(t)
            
    # Add additional points for interpolation to edge of head
    xy = np.concatenate((xy, np.array([[-1, -1], [-1, 1], [1, -1], [1, 1]])), axis=0)
    z = np.concatenate((z, np.zeros((4,))), axis=None)

    # Make grid
    N = 300
    xi = np.linspace(-2, 2, N)
    yi = np.linspace(-2, 2, N)
    zi = griddata((xy[:, 0], xy[:, 1]), z, (xi[None,:], yi[:,None]), method="cubic", fill_value="nan")

    # Set points outside radius to nan so they will not be plotted (outside head).
    d = xi[1] - xi[0]
    for i in range(N):
        for j in range(N):
            if np.sqrt(xi[i]**2 + yi[j]**2) + d > 1:
                zi[j, i] = "nan"

    # Make figure
    fig = plt.figure()
    ax = fig.add_subplot(111, aspect=1)
    
    # Add head
    circle = Circle(xy=[0,0], radius=1, edgecolor="k", facecolor="w", zorder=1)
    ax.add_patch(circle)

    # Add ears
    circle = Ellipse(xy=[-1,0], width=0.25, height=0.5, angle=0, edgecolor="k", facecolor="w", zorder=0)
    ax.add_patch(circle)
    circle = Ellipse(xy=[1,0], width=0.25, height=0.5, angle=0, edgecolor="k", facecolor="w", zorder=0)
    ax.add_patch(circle)

    # Add a nose
    polygon = Polygon(xy=[[-0.1,0.9], [0,1.25],[0.1,0.9]], edgecolor="k", facecolor="w", zorder=0)
    ax.add_patch(polygon) 

    # Add the interpolated data
    cs = ax.contourf(xi, yi, zi, 60, cmap=plt.cm.jet, zorder=2)
    ax.contour(xi, yi, zi, 15, colors="grey", zorder=3)

    # Add data points
    ax.scatter(xy[:-4,0], xy[:-4,1], marker="o", c="k", s=15, zorder=4)
    
    # Add color bar
    if cbar:
        fig.colorbar(cs, ax=ax)

    # Make the axis invisible 
    plt.axis("off")

    # set axes limits
    ax.set_xlim(1.25, -1.25)
    ax.set_ylim(-1.25, 1.25)

# %%
def confusionmatrix(T, Y):
    """
    Function to plot a confusion matrix.
    
    Args:
        T (ndarray): target labels
        Y (ndarray): predicted labels
    """

    # Confusion matrix
    cm = confusion_matrix(T.flatten(), Y.flatten())

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           ylabel="True label",
           xlabel="Predicted label")

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, "{}".format(cm[i, j]),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()

# %% [markdown]
# # 1. The dataset <a class="anchor" id="dataset"></a>
# Download the data to a specific location on your computer, and change the variable `path_to_data` accordingly.

# %%
path_to_data = "/content/drive/My Drive/Brain_reading/assignment1_data.npz"

# %% [markdown]
# To load the data, execute the cell below. It loads into memory a training set and a validation set of one participant. We will use the training set to inspect the data and calibrate a classifier, and the validation set to evaluate the performance of the classifier. In fact, in the original competition, one was not given the target values of the validation set, which had to be predicted and submitted and were evaluated to get a position on the [leaderboard](http://www.bbci.de/competition/ii/results/index.html).
#
# Some words on the dataset:
# * $X \in \mathbb{R}^{k, m, c}$ are the EEG data of $k$ single-trials, $m$ samples, and $c$ channels. With single-trials we mean the participant is foxussing on one symbol. With samples we mean time-points (to convert samples to time, use the samplefrequency, i.e., the number of samples per second (Hz)). With channels we mean the voltage difference between a recording and reference electrode.
# * $Y \in \mathbb{R}^{k, m, n}$ are the codebooks of $k$ single-trials, $m$ samples, and $n$ classes. With classes we mean each possible symbol in the speller. This codebook represents whether or not a cell at a specific location flashed at a certain timepoint.
# * $T \in \mathbb{R}^{k}$ are the target labels of $k$ single-trials. This representes the ground truth of one of 36 cells that the participant attended to.

# %%
# Load the data
tmp = np.load(path_to_data)
X_train = tmp["X_train"]
Y_train = tmp["Y_train"]
T_train = tmp["T_train"]
X_valid = tmp["X_valid"]
Y_valid = tmp["Y_valid"]
T_valid = tmp["T_valid"]
channels = tmp["channels"].tolist()
fs = tmp["fs"]

# Print some properties
print("Data has timeseries of {} channels at {} Hz".format(len(channels), fs))
print("Channels:", channels)
print("Training data:")
print("\tX: ", X_train.shape, X_train.dtype)
print("\tY: ", Y_train.shape, Y_train.dtype)
print("\tT: ", T_train.shape, T_train.dtype)
print("Validation data:")
print("\tX: ", X_valid.shape, X_valid.dtype)
print("\tY: ", Y_valid.shape, Y_valid.dtype)
print("\tT: ", T_valid.shape, T_valid.dtype)
# Out:
# Data has timeseries of 64 channels at 240 Hz
# Channels: ['Fc5', 'Fc3', 'Fc1', 'Fcz', 'Fc2', 'Fc4', 'Fc6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'Cp5', 'Cp3', 'Cp1', 'Cpz', 'Cp2', 'Cp4', 'Cp6', 'Fp1', 'Fpz', 'Fp2', 'Af7', 'Af3', 'Afz', 'Af4', 'Af8', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'Ft7', 'Ft8', 'T7', 'T8', 'T9', 'T10', 'Tp7', 'Tp8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'Po7', 'Po3', 'Poz', 'Po4', 'Po8', 'O1', 'Oz', 'O2', 'Iz']
# Training data:
# 	X:  (85, 7794, 64) float32
# 	Y:  (85, 7794, 36) bool
# 	T:  (85,) uint8
# Validation data:
# 	X:  (100, 7794, 64) float32
# 	Y:  (100, 7794, 36) bool
# 	T:  (100,) uint8

# %% [markdown]
# ### 1.1. The stimulus paradigm (0.25 points) <a class="anchor" id="stimulus"></a>
# Let's start with inspecting what the participant had seen during the experiment. For this we use the variable `Y_train`, which represents an indicator function that is 1 whenever a flash happened in the $k$th trial at the $m$th sample for the $n$th class.
#
# Let's visualize one of the trials to get a feel of what `Y_train` represents. Take for instance the first trial, and plot with `plt.plot()` the timecourses as individual lines in one figure. To make them "stacked" (i.e., not overlapping), you can add a bias to the timecourses. For example, plot the $i$th class as $y=i + 0.8 * Y_{i}$. Make sure the x-axis represents time, not samples (think about the difference), and add sensible labels to the axes.
#
# This plot shows the *codebook* for this particular trial, which we need for classification later on.
#
# From this plot, try to infer what the subject saw. Can you derive whether at a certain timepoint a row or column was shown? Can you also derive which row or column, knowing that they were presented in a grid of $6 \times 6$ cells?

# %%
#Increase plot size, lots of data to fit
plt.figure(figsize=(20,10))

#Iterate each class
for i in range(Y_train.shape[2]):
  #Plot the class's timeseries (with bias)
  plt.plot(i + 0.8 * Y_train[0,:,i])

#Convert iterations to second time ticks using frequency
ticks = np.arange(0, Y_train.shape[1], step=240)
plt.xticks(ticks=ticks,labels=ticks/240.)

#Y-labels are kinda meaningless for biased binary activations, so remove.
plt.yticks([])

#Graph fancifications
plt.ylabel("Binary Flash Indication")
plt.xlabel('Time (seconds)')
plt.show()

# %% [markdown]
# Of course, instead of visualizing the timecourses as they are represented in `Y_train`, we can also reconstruct what the participant saw. Recall that the grid was a $6 \times 6$ grid. `Y_train` denotes for each cell in this grid wheter it was "on" or "off". From the description of the dataset, we know that the flashes were of 100 ms duration with 75 ms inter-flash interval (ie.e., a blank screen). This means that each 175 ms a new flash happened.
#
# Now, let's take the same trial as before (e.g. the first), and go trough it in steps of 175 ms to plot the $6 \times 6$ grid for the first 20 flashes. For this you can use `plt.subplots()` and `plt.imshow()`. Specifically, fill a grid of $6 \times 6$ with zeros, and put ones at those places that were flashed at that timepoint, then plot this.
#
# Let's also add in the attended cell. The variable `T_train` denotes the attended cell. Add this information to your grid by assigning a value of 2 to the attended target in the grid.
#
# This visualization should show you the rows and columns as flashed during each *epoch*. Did your interpretation of the rows and columns from the codebook above match the reality? Also, can you make predictions about for which epochs a P300 response would be elicited and for which not?

# %%
#240Hz * 175ms * 180epochs
ms_ticks = np.arange(0, 240 * 0.175 * 180, step=240 * 0.175) 

print("Number of epochs: ", len(ms_ticks))
print("Starting Index of each epoch: \n", ms_ticks)

"""
Total time steps, - minus the index of final stimulus,
= equals the "time left over" after the final stimulus.
"""
7794 - 7518 # == 276

"""
Therefore, if we take windows of size 276,
the batches will fit perfectly.

If we wish to take smaller / larger batches,
the final number of samples will be mis-matched,
so we must pad the final batch up to the desired window size.
"""
# Out:
# Number of epochs:  180
# Starting Index of each epoch:
#  [   0.   42.   84.  126.  168.  210.  252.  294.  336.  378.  420.  462.
#   504.  546.  588.  630.  672.  714.  756.  798.  840.  882.  924.  966.
#  1008. 1050. 1092. 1134. 1176. 1218. 1260. 1302. 1344. 1386. 1428. 1470.
#  1512. 1554. 1596. 1638. 1680. 1722. 1764. 1806. 1848. 1890. 1932. 1974.
#  2016. 2058. 2100. 2142. 2184. 2226. 2268. 2310. 2352. 2394. 2436. 2478.
#  2520. 2562. 2604. 2646. 2688. 2730. 2772. 2814. 2856. 2898. 2940. 2982.
#  3024. 3066. 3108. 3150. 3192. 3234. 3276. 3318. 3360. 3402. 3444. 3486.
#  3528. 3570. 3612. 3654. 3696. 3738. 3780. 3822. 3864. 3906. 3948. 3990.
#  4032. 4074. 4116. 4158. 4200. 4242. 4284. 4326. 4368. 4410. 4452. 4494.
#  4536. 4578. 4620. 4662. 4704. 4746. 4788. 4830. 4872. 4914. 4956. 4998.
#  5040. 5082. 5124. 5166. 5208. 5250. 5292. 5334. 5376. 5418. 5460. 5502.
#  5544. 5586. 5628. 5670. 5712. 5754. 5796. 5838. 5880. 5922. 5964. 6006.
#  6048. 6090. 6132. 6174. 6216. 6258. 6300. 6342. 6384. 6426. 6468. 6510.
#  6552. 6594. 6636. 6678. 6720. 6762. 6804. 6846. 6888. 6930. 6972. 7014.
#  7056. 7098. 7140. 7182. 7224. 7266. 7308. 7350. 7392. 7434. 7476. 7518.]
# '\nTherefore, if we take windows of size 276,\nthe batches will fit perfectly.\n\nIf we wish to take smaller / larger batches,\nthe final number of samples will be mis-matched,\nso we must pad the final batch up to the desired window size.\n'

# %%
#Convert from sample iterations to seconds
ms_ticks = np.arange(0, 240 * 0.175 * 20, step=240 * 0.175) #240Hz * 175ms
ms_ints = [int(m) for m in ms_ticks]
print(ms_ints)

#Iterate 20 trials (240 * 0.175 * 20)
for i,ts in enumerate(ms_ints):

  #Extract all classes, of the i'th flash, from first trial
  img = Y_train[0, ts, :]

  #Cast image from boolean to binary
  img = img.astype('int')

  #Add attended cell value
  img[T_train[0]] = 2
      
  #Reshape into 6x6 image
  img = img.reshape(6,6)

  #Plot images
  plt.subplot(4,5,i+1)
  plt.imshow(img, cmap='coolwarm')
# Out:
# [0, 42, 84, 126, 168, 210, 252, 294, 336, 378, 420, 462, 504, 546, 588, 630, 672, 714, 756, 798]

# %% [markdown]
# ### 1.2. The EEG data (0.25 points) <a class="anchor" id="eeg"></a>
# So far, we discussed what `Y_train` and `T_train` mean -- the codebook and the targets. Let's inspect the EEG data in `X_train`. With the data, we have a list of the channel names `channels` so we know which channel was located where on the scalp, and we have the sample frequency `fs`, i.e., the number of measurements per second.
#
# Now, plot a trial (e.g., again the first) of channel Cz using `plt.plot()`. You can, in python, easily find the index of an item in a list with e.g. `channels.index("Cz")`. Add sensible labels to the axes.
#
# Can you interpret the data visually, i.e., can you derive which cell the participant attended to?

# %%
#Increase plot size, lots of data to fit
plt.figure(figsize=(16,8))

plt.plot(X_train[0, :, channels.index("Cz")])

#Convert iterations to second time ticks using frequency
ticks = np.arange(0, Y_train.shape[1], step=240)
plt.xticks(ticks=ticks,labels=ticks/240.)

#Fancification
plt.xlabel("Time (seconds)")
plt.ylabel("Voltage")
plt.show()

# %% [markdown]
# The above visualization shows us the data in the temporal domain. Let's transform this data to the frequency-domain and inspect which frequencies are present in the data.
#
# Compute the frequency spectrum (i.e., power spectral density) of `X_train` using `periodogram()` from SciPy. Make sure the power spectrum is computed over the correct axis and with the correct samplefrequency! If you do not know how to do so, google its documentation! Then, plot the frequency spectrum of the same trial as above for channel Cz using `plt.plot()`. Add sensible labels to the axes.
#
# What do you observe? What can you say about the peaks in the lower spectrum, and what can you say about the peak at 60 Hz? Also, why do we see frequencies only up to 120 Hz when in fact our samplefrequency is higher?

# %%
#Take same timeseries as above; 
#First trial, all samples, from the Cz channel
f, Pxx_den = periodogram(X_train[0,:,channels.index("Cz")],fs=240.0)

#Plotting. See https://docs.scipy.org/doc/scipy-0.13.0/reference/generated/scipy.signal.periodogram.html
plt.semilogy(f, Pxx_den)
plt.xlabel('Frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')

plt.show()

# %% [markdown]
# # 2. Preprocessing<a class="anchor" id="preproc"></a>
# An important step in BCI is to clean the data from artefacts and noise-sources not relevant to the signal, and to enhance features in the signal to boost SNR. As we saw above, the data contains some frequencies we are not interested in, for instance the 60 Hz peak. Additionally, we know that ERPs tend to be slow.

# %% [markdown]
# ### 2.1. Spectral filter (0.5 points) <a class="anchor" id="spectralfilter"></a>
# Implement a low-pass filter with a cut-off frequency of 20 Hz and a high-pass filter with a cut-off at 0.1 Hz. To design the filter, use `butter()` from SciPy, and to apply the filter use `filtfilt` from SciPy. Note, there is plenty of choice in filter types and filter parameters to choose from. Here, use a 5th order filter in both cases. Again, make sure this is done with the right sample frequency and over the right axis.
#
# Apply the low-pass and high-pass to both `X_train` and `X_valid`, and make sure you use this spectrally filtered data throughout the remainder of this assignment.
#
# What does the low-pass filter do? What does the high-pass filter do? If you cannot answer these questions directly, look at what the data looks like before and after filtering.

# %%
#Low Pass Filter
low_b, low_a = butter(5, 20, btype="low", fs=240.0)
lf_signal = filtfilt(low_b, low_a, X_train, axis=1)

#High Pass Filter
high_b, high_a = butter(5, 0.1, btype="high", fs=240.0)
hf_signal = filtfilt(high_b, high_a, X_train, axis=1)

#Both Filters (order shouldn't matter)
X_train = filtfilt(high_b, high_a, filtfilt(low_b, low_a, X_train, axis=1), axis=1)
X_valid = filtfilt(high_b, high_a, filtfilt(low_b, low_a, X_valid, axis=1), axis=1)

#Increase plot size, lots of data to fit
plt.figure(figsize=(16,8))

plt.plot(lf_signal[0, :, channels.index("Cz")], label="Low Pass")
plt.plot(hf_signal[0, :, channels.index("Cz")], label="High Pass")
plt.plot(X_train[0, :, channels.index("Cz")], label="Both")

#Convert iterations to second time ticks using frequency
ticks = np.arange(0, Y_train.shape[1], step=240)
plt.xticks(ticks=ticks,labels=ticks/240.)

#Fancification
plt.xlabel("Time (seconds)")
plt.ylabel("Voltage")
plt.legend()
plt.show()

# %% [markdown]
# ### 2.2. Downsampling (0.5 points) <a class="anchor" id="downsampling"></a>
# Another step is to downsample the data. In many cases, EEG data is acquired at very high samplefrequencies even up to 2 KHz. Eventhough this adds temporal information, it might be redundant for classification since the actual phenomenon that we are interested in -- here ERPs -- typically do not happen at these high frequencies. Additionally, having a high samplefrequency means we have a lot of datapoints, each for which we will need to fit parameters later on. Building a simpler model is commonly better (e.g., to avoid overfitting) so having less *features* might be relevant.
#
# Let's downsample the data to 40 Hz. The data was acquired at 240 Hz. We have already applied an anti-aliasing filter at the previous step (i.e., 20 Hz low-pass), so we can safely *decimate* the data to 40 Hz. This is done by simply sampling evenly spaced samples from the data along the temporal axis. Do this for both `X_train` and `X_valid`, and for `X` as well as `Y`.
#
# Yes, there is a SciPy decimate function, or resample, but really, you can do this by hand, so please do so, so you understand clearly what decimation is. Specifically, do not use any (SciPy) methods here!

# %%
#240Hz / 40Hz = 6
decimated_X_train = X_train[:, ::6, :]
decimated_X_valid = X_valid[:, ::6, :]

print(decimated_X_train.shape, decimated_X_valid.shape)
# Out:
# (85, 1299, 64) (100, 1299, 64)

# %% [markdown]
# ### 2.3. Trick for offline analysis<a class="anchor" id="trick"></a>
# The cell below reorders `Y` such that the target is always at the end, i.e., `Y[:,:,-1]` denotes the target codebook. This is easy for data handling, as we do not need to look up the target codebook from `Y` with `T` anymore. This just saves us from a lot of bookkeeping. Remember, from this point onward, target/nontarget labels for *epochs* are identified by `Y[:,:,-1]`, and target labels for *single-trials* are always $n-1$ (minus one as we start counting from 0).
#
# Yes, this means that from this point ontward we cannot relate targets to cells anymore, as we essentially throw away that information. For now, this is fine, since we do an offline analysis. In an online experiment, this trick can still be performed during the training stage, but cannot be applied during the testing phase. However, in an online experiment during the testing phase, we deal with one single-trial at a time, for which we do not know the target, so this trick is irrelevant in such a scenario anyway. Once more, it is used here for convenience only.

# %%
def put_target_last(Y, T):
    for i in range(T.size):
        Y[i, :, [-1, T[i]]] = Y[i, :, [T[i], -1]] # swap target with last
    T = (Y.shape[2] - 1) * np.ones((Y.shape[0]), dtype="uint8") # target becomes last always
    return Y, T

# Put target at end
Y_train, T_train = put_target_last(Y_train, T_train)
Y_valid, T_valid = put_target_last(Y_valid, T_valid)

# %% [markdown]
# # 3. Data slicing<a class="anchor" id="slicing"></a>

# %% [markdown]
# The classification problem at hand is a two-class problem: target versus non-target or attended versus non-attended. Whenever the attended cell was flashed, a P300 is expected. Note, via this two-class problem, we will later on derive to which of 36 cells the participant was attending, which is a multi-class problem.
#
# We will use *block-processing*: the classification will be applied every time a flash happened (i.e., every *epoch*), because we want to know whether at that point in time this flash happened at the attended cell. If so, it should evoke a P300, if not no P300 is evoked.
#
# The first step then is to slice the trials into individual *epochs*. We know from the description that every row and column was flashed 15 times for 100 ms with 75 ms gaps, for a total of $12*15=180$ epochs each every 175 ms for each trial.
#
# Write a function `slice_data(X, Y, epoch_size)` that takes windows of data starting at these flashes. The size of the window is defined by `epoch_size`, and should cover the P300 response (think about this). Slice both `X_train` and `X_valid`, and also `Y_train` and `Y_valid`, and call the sliced data `sX_train`, `sX_valid`, `sY_train`, and `sY_valid` (i.e., the function outputs `sX` and `sY`). The dimensions should become $X \in \mathbb{R}^{k,s,c,m}$ and $Y \in \mathbb{R}^{k,s,n}$ with $k$ the number of trials, $s$ the number of epochs, $c$ the number of channels, $m$ the window size, and $n$ the number of classes.

# %% [markdown]
# ### 3.1 Slicing to epochs (1.0 points) <a class="anchor" id="epochs"></a>

# %%
"""Epoch size must cover P300 response
#From paper: (C)overt attention and visual speller design in an ERP-based brain-computer interface
"[P300] occurring at 300-500 ms post-stimulus"

If we use an epoch size of 276, the window divides nice and cleanly.
However, it may not be long enough to capture the whole P300 response"""

def slice_data(X, Y, epoch_size=276):
  #Must be same size for X & Y, but I'm too lazy to validate it...
  trials = X.shape[0]
  #Known number of flashes per trial
  epochs = 180
  Hz = 240

  #Arange new output shapes
  #k, s, c, m
  Xs = np.empty(shape=(trials, epochs, X.shape[2], epoch_size))
  #k, s, c
  Ys = np.empty(shape=(trials, epochs, Y.shape[2]))

  for k in range(trials):
    #Finds starting step of each epoch
    #240Hz * 180 epochs * 0.175 s/epoch
    epoch_steps = np.arange(0, Hz * 0.175 * epochs, step= Hz * 0.175, dtype='int')
    #Split into batches -
    #Enumerate a mapping from samples to epoch windows
    for i,s in enumerate(epoch_steps):
      #Has shape WindowSamples x Channels, but we want (k,s,c,m)
      x_window = X[k, s:s+epoch_size, :]
      x = np.swapaxes(x_window,0,1)
      """
      #We may desire to look at windows of different sizes.
      #In this case, we only have two real options -
      Pad the final batch, or exclude it entirely.
      #We'll go with padding to preserve the correct number of epochs.
      #Many modes to choose from, 
      but either way this is batch could be kinda useless if a bad epoch_size is chosen.
      """
      if x.shape[1] != epoch_size:
        pad = abs(epoch_size - x.shape[1])
        npad = ((0, 0), (0, pad)) #Pad amount for (Channels(before, after), Samples(before, after))
        x = np.pad(x, npad, mode="mean")

      #Slice & Dice into new shape
      Xs[k, i] = x
      Ys[k, i] = Y[k, s, :]

  return Xs, Ys

sX_train, sY_train = slice_data(X_train, Y_train, epoch_size=500)
sX_valid, sY_valid = slice_data(X_valid, Y_valid, epoch_size=500)

# %%
# Print some properties
n_trials, n_epochs, n_channels, n_samples = sX_train.shape
n_trials, n_epochs, n_classes = sY_train.shape

print("Training")
print("sX", sX_train.shape, sX_train.dtype)
print("sY", sY_train.shape, sY_train.dtype)

print("Validation")
print("sX", sX_valid.shape, sX_valid.dtype)
print("sY", sY_valid.shape, sY_valid.dtype)
# Out:
# Training
# sX (85, 180, 64, 500) float64
# sY (85, 180, 36) float64
# Validation
# sX (100, 180, 64, 500) float64
# sY (100, 180, 36) float64

# %% [markdown]
# ### 3.2. Temporal response (0.5 points)<a class="anchor" id="temporal"></a>
# Now that we sliced the data, the fun can start. A first thing to check is that we sliced the data correctly and that we actually recorded a nice P300 response. We can do so by computing the actual ERP in the training data. For this we do not care about different trials, so we reshape `sX` and `sY` to $X \in \mathbb{R}^{k*s,c,m}$ and $Y_s \in \mathbb{R}^{k*s,n}$. Also, note that we had put the target/non-target information at the back of `Y`, so we can take target/non-target label information by taking `sY[:,:,-1]`.
#
# With this information, compute the mean over all target and non-target epochs separately. Then, plot the ERPs for the channels Fpz, Cz, Pz, and O1 in separate figures while overlaying the target and non-target ERP. Specifically, use `plt.subplots` to create 4 figures, and plot the two ERPs with `plt.plot()`. Add a legend so you know which one is which, add sensible labels to the axes, and again make sure the x-axis represents time, not samples.
#
# Also, print how many targets and how many non-targets are in the training data. Why do we have more non-targets?
#
# What can you observe from the visualization? Which channel do you think contains the most information? Do you see differences between frontal, central, parietal or occipital electrodes? What explains these differences?
#
# Note, we now only plotted the averages. In most cases, you would also want to see the variance. Do you have an idea as to why?

# %%
#Find ERP by reshaping k*s
X_erp = sX_train.reshape(sX_train.shape[0] * sX_train.shape[1], sX_train.shape[2], sX_train.shape[3])
Y_erp = sY_train.reshape(sY_train.shape[0] * sY_train.shape[1], sY_train.shape[2])
print(X_erp.shape, Y_erp.shape)


X_erp_valid = sX_valid.reshape(sX_valid.shape[0] * sX_valid.shape[1], sX_valid.shape[2], sX_valid.shape[3])
Y_erp_valid = sY_valid.reshape(sY_valid.shape[0] * sY_valid.shape[1], sY_valid.shape[2])

#If Y_erp == 0, non target
tidxs = np.where(Y_erp[:,-1]==1)
ntidxs = np.where(Y_erp[:,-1]==0)

#Split by the index of same trials in X_erp
targets = X_erp[tidxs, :, :][0]
non_targets = X_erp[ntidxs, :, :][0]

"""
There are 5 times as many non-targets as targets,
because each epoch 
"""
print(targets.shape, non_targets.shape)

"""Means are computed over all epochs,
  which is the first dimension,  k*s """
mean_targets = np.mean(targets, axis=0)
mean_non_targets = np.mean(non_targets, axis=0)
print(mean_targets.shape, mean_non_targets.shape)
# Out:
# (15300, 64, 500) (15300, 36)
# (2550, 64, 500) (12750, 64, 500)
# (64, 500) (64, 500)

# %%
#Get channel indexes
idxs = ["Fpz", "Cz", "Pz", "O1"]
cidxs = [channels.index(i) for i in idxs]

# #Plot desired channels
for i,c in enumerate(cidxs):

  c_targets = mean_targets[c, :]
  c_non_targets = mean_non_targets[c, :]

  plt.subplot(2,2,i+1)

  plt.plot(range(c_targets.shape[0]),c_targets,label="Target")
  plt.plot(range(c_targets.shape[0]),c_non_targets,label="Non-Target")
  #Fancification
  plt.xlabel("Time (ms)")
  plt.ylabel("Voltage")
  plt.legend()


plt.show()

# %% [markdown]
# ### 3.3. Spatial response (0.5 points) <a class="anchor" id="spatial"></a>
# Apart from a temporal profile, an ERP always comes with a spatial profile too. This profile might be time dependent. Let's visualize the spatial distribution at two timepoints. Use the `topoplot` function with the electrode layout in `assignment1_channels.txt` and plot the spatial distribution of the target ERP at 175 ms and at 400 ms.
#
# What do you observe? Can you explain the two topographies?

# %%
#Ah crap these aren't miliseconds, gotta convert...
#But wait, 400 miliseconds is more than 2 epochs
topoplot(z=mean_targets[:,175],c="/content/drive/My Drive/Brain_reading/assignment1_channels.txt")
topoplot(z=mean_targets[:,400],c="/content/drive/My Drive/Brain_reading/assignment1_channels.txt")

# %% [markdown]
# # 4. Decoding the neural code<a class="anchor" id="decoding"></a>
# The above ERP looks beautiful, but as you can read from your printed information, it is the average of many repetitions. Instead, the BCI has to work out whether a single epoch is a target or a non-target. Let's see how we can do this.

# %% [markdown]
# ### 4.1. Classifier calibration (0.5 points)<a class="anchor" id="calibration"></a>
#
# Write a function `calibrate(sX, sY)` that takes in the training data and uses the full timeseries of Cz to classify an epoch. For classification we first use a *post-processing* step that normalizes the data. For this we use the `StandardScaler()` from sklearn. In the second step we use the `LinearDiscriminantAnalysis()` classifier from sklearn. For this classifier, set the solver to "eigen" and shrinkage to "auto". Those two steps can be conveniently packed together in a "pipeline" by making use of sklearn's `make_pipeline()`. The function should output the pipeline.
#
# To calibrate a pipeline we just call the `fit()` method on the pipeline with the inputs (`sX`) and targets (`sY`). In sklearn, these have to be a 2D matrix (examples by features) and a 1D (examples) respectively. Since we classify epochs, we again forget about the trial information and reshape `sX` to $X \in \mathbb{R}^{k*s,m}$ -- note we took only Cz (feature selection) --, and `sY` to $Y \in \mathbb{R}^{k*s}$ -- note we take the last entry again which contains the target.
#
# Use the function to calibrate your LDA classifier on the training data.
#
# In this setting -- using Cz only -- we fit a temporal filter. In a similar vein, when we instead specify one timepoint and keep all channels, we fit a spatial filter. Ultimately, one can fit a spatiotemporal filter by keeping both spatial as well as temporal information. To do so, one can flatten the two dimensions, i.e., vectorize the features. For now, we stick with a temporal filter.

# %%
def calibrate(X_erp, Y_erp):
  #Extracting just the Cz channel, from every epoch (k*s).
  cz_id = channels.index("Cz")
  sX = X_erp[:, cz_id, :]

  #Take targets from the end of Y, for every epoch (k*s).
  sY = Y_erp[:, -1]

  pipeline = make_pipeline(StandardScaler(), LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto'))

  pipeline.fit(sX, sY)

  return sX, sY, pipeline

# %% [markdown]
# ### 4.2. Epoch prediction (0.5 points) <a class="anchor" id="ep"></a>
# Given the trained classifier, we can start to classify new epochs. Write a function `predict_epochs(pipeline, sX)` that receives the calibrated pipeline and data `sX`. It should perform the same feature selection process that the training procedure followed (i.e., vectorizing trials and epochs and selecting Cz).
#
# Then, to apply the classifier, normally one would use the `predict()` function of the pipeline. Instead, here we use the `decision_function()` method to get raw scores.
#
# Next, convert these raw scores to probabilities by applying a *sigmoid*, i.e. $f(x)=\frac{1}{1+e^{-x}}$. This now represents the probability of the input being a target or not. Then, extend this vector with the probability of not being a target (i.e., $1-p$). Finally, reshape this matrix back to the original shape so that the output of this function becomes $P \in \mathbb{R}^{k,s,2}$, denoting the probability of each trial's epoch to be one of the two classes (i.e., flash/no-flash, P300/no-P300.
#
# Use this function to predict the probabilities for both training as well as validation data. Call these probabilities `sP_train` and `sP_valid`, i.e., the probabilities for sliced training and validation data.

# %%
#Define vectorized sigmoid function
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
sigmoid_f = np.vectorize(sigmoid)

#Assume sX shape is in format [k*s, m], 
#and must cast to origin shape +(,2), resulting in [k,s,2]
def predict_epochs(pipeline, sX, origin_shape=(85,180)):
  #Make predictions
  raw_scores = pipeline.decision_function(sX)
  #Apply sigmoid and invert
  sig_scores = sigmoid_f(raw_scores)
  inv_scores = 1. - sig_scores

  #Stack into [k*s, 2], with probability sum of 1.0 across stack
  sP = np.stack( (sig_scores, inv_scores) , axis=-1)

  #Reshape k*s -> k,s using origin_shape param
  return sP.reshape( (*origin_shape,2) )
  

sXt, sYt, train_pipeline = calibrate(X_erp,Y_erp)
sP_train = predict_epochs(train_pipeline, sXt)

#Train a pipeline on the validation data?
#Or re-use the train_pipe to predict the validation?
sXv, sYv, _ = calibrate(X_erp_valid,Y_erp_valid)
sP_valid = predict_epochs(train_pipeline, sXv, origin_shape=(100,180))


print(f"sP Train: {sP_train.shape} \n sP Validation: {sP_valid.shape}")
# Out:
# sP Train: (85, 180, 2)
#  sP Validation: (100, 180, 2)

# %% [markdown]
# ### 4.3. Epoch classification (0.5 points) <a class="anchor" id="ec"></a>
# To classify an epoch, we simply maximize its probability of being a target or non-target. Write a function `classify_epochs(sP)` that receives the probabilities and outputs per trial and epoch whether it was a target or non-target, i.e., it outputs `sYh`.
#
# Apply the function to the predicted probabilities of the training and validation data. With these, you can compute a training an validation performance of classifying P300 responses (targets versus non-targets), by comparing them with the accompanying ground truth labels in `sY`. Compute the classification accuracies for both training and validation data. Additionally, plot confusion matrices using the `confusionmatrix()` function.
#
# Note, this classifier will highly likely perform quite bad. Think about why this is so. Even when it is performing really bad, could we use it for classification at the trial-level, where we combine multiple epochs? Please continue to the next exercises, eventhough your classifier might not make sense at first.

# %%
def classify_epochs(sP):
  return np.argmax(sP, axis=-1)

sYht = classify_epochs(sP_train).flatten()#Flatten trials
sYhv = classify_epochs(sP_valid).flatten()

print("Training Accuracy Score: ", np.mean(sYt==sYht))
confusionmatrix(sYt, sYht)

print("Validation Accuracy Score: ", np.mean(sYv==sYhv))
confusionmatrix(sYv, sYhv)
# Out:
# Training Accuracy Score:  0.16856209150326798
# Validation Accuracy Score:  0.16666666666666666

# %% [markdown]
# ### 4.4. Trial prediction (0.5 points) <a class="anchor" id="tp"></a>
# The goal of the P300 speller is not to comunicate target versus non-target information, but instead to communicate to which cell the participant is attending, i.e., which symbol the participant wants to select. For this we use the epoch predictions, i.e., the probabilities of an epoch within a trial being a target or not.
#
# Write a function `predict_trials(pipeline, sX, sY)` that first uses `predict_epochs()` to get the probabilities `sP` for `sX`. Then, since we have multiple cells to work with, we will aggregate the information per cell given the information in the codebook `sY`. Make a variable `P` with dimensions $P \in \mathbb{R}^{k, s, n}$, that takes probability $p$ if there was a flash for the $n$th cell in the $k$th trial and the $p$th epoch, and otherwise $1-p$.
#
# Apply this function to both training as well as validation data. Basically, this function makes the conversion from the two-class target versus non-target problem to the multi-class symbols problem.

# %%
  """Sorry, but I honestly have to take a blind guess at what 'cells' means here.
  The incredibly non-descript and recycled variable names are truly awful.

  Originally, 'sY' had shape [trials, epochs, cells], where cells=36.

  But following on from Sections 4.1 and 4.2,
  it's explicitly stated that we're reshaping 'sY',
  By taking only index -1 for offline analysis. 
  
  So 'sY' now has shape [trials * epochs]
  after running the calibrate() function.

  I guess you're expecting me to ignore the 'sY' which we just calculated?
  Undo ALL the steps done to Y in this section, 
  including the one written in literally the last question,
  and use the OTHER 'sY' variables which we calculated back in Section 3.2.
  Obviously.


  I apologise for the rant, but this is making my head hurt.
  Love the notebook practicals in general, don't get me wrong.
  """
# Out:
# "Sorry, but I honestly have to take a blind guess at what 'cells' means here.\nThe incredibly non-descript and recycled variable names are truly awful.\n\nOriginally, 'sY' had shape [trials, epochs, cells], where cells=36.\n\nBut following on from Sections 4.1 and 4.2,\nit's explicitly stated that we're reshaping 'sY',\nBy taking only index -1 for offline analysis. \n\nSo 'sY' now has shape [trials * epochs]\nafter running the calibrate() function.\n\nI guess you're expecting me to ignore the 'sY' which we just calculated?\nUndo ALL the steps done to Y in this section, \nincluding the one written in literally the last question,\nand use the OTHER 'sY' variables which we calculated back in Section 3.2.\nObviously.\n\n\nI apologise for the rant, but this is making my head hurt.\nLove the notebook practicals in general, don't get me wrong.\n"

# %%
def predict_trials(pipeline, sX, sY, epochs=180, origin_shape=(85, 180)):
  trials = sY.shape[0] // epochs
  cells=32
  sP = predict_epochs(pipeline, sX, origin_shape)

  P = np.zeros_like(sY)
  #For every trial and epoch
  for k in range(sP.shape[0]):
    for s in range(sP.shape[1]):
      #For each pixel cell in 6x6
      for n in range(cells):
        #If there was a flash, Take p
        if sY[k,s,n]:
          P[k,s,n] = sP[k,s,0]
        else:
          # Else no flash, Take 1 - p
          P[k,s,n] = sP[k,s,1]

  return P


p_train = predict_trials(train_pipeline, sXt, sY_train)
p_valid = predict_trials(train_pipeline, sXv, sY_valid, origin_shape=(100,180))

print(f"p Train: {p_train.shape} \n p Validation: {p_valid.shape}")
# Out:
# p Train: (85, 180, 36)
#  p Validation: (100, 180, 36)

# %% [markdown]
# ### 4.5. Trial classification (0.5 points) <a class="anchor" id="tc"></a>
# Now we are finally ready to classify trials. The `P` variables contain all information we need. Basically, they denote how likely the $n$th class is at the $k$th trial and $s$th epoch. We will accumulate the information that we have over multiple epochs to form a decision.
#
# Write a function `classify_trials(P)` that takes the probabilities, sums the evidence over epochs for individual symbols and trials, and emits the decision by maximizing this evidence over symbols. This function outputs `Yh` which is a vector with $k$ predictions, one for each trial.
#
# Predict the labels for both the training as well as the testing data. From these we can directly compute the trial-level classification accuracy by comparing with `T` (remember, the ground truth label is always $n-1$). Compute the performance for both training and validation data.
#
# Did the classifier perform well?

# %%
def classify_trials(P):
  Ks = []
  for k in range(P.shape[0]):
    Ks.append(np.argmax(np.sum(P[k], axis=0)))
  return np.array(Ks)

Yht = classify_trials(p_train)
Yhv = classify_trials(p_valid)

#Apparently there's code which mutates T_train for offline analysis, 
#making it useless here.
#Gotta re-aquire.

T_train = tmp["T_train"]
T_valid = tmp["T_valid"]


print("Training Accuracy Score: ", np.mean(Yht==T_train))
print("Validation Accuracy Score: ", np.mean(Yhv==T_valid))
# Out:
# Training Accuracy Score:  0.011764705882352941
# Validation Accuracy Score:  0.06

# %% [markdown]
# ### 4.6. Decoding curves (0.5 points) <a class="anchor" id="dc"></a>
# Apart from classification accuracy, an important aspect of BCI is how long classification takes. For example, which classifier would you prefer, one that is 99% correct but takes 10 minutes per selection, or one that is 80% correct and takes 10 seconds per selection? The answer to this question might depend on what we use the BCI for, but to be able to answer the question, we need to compute *decoding curves*. Decoding curves show the classification accuracy as a function of the amount of data used for classification. In general, of course, more data would result in higher classification.
#
# Since our `P` estimates are already expressed as $P \in \mathbb{R}^{k, s, n}$, we can show the effect of integration length on classification performance. Write a loop over epochs ($p$) and perform the classification on all epochs until the current epoch (i.e., evidence is only accumulated until that epoch). Store these decoding accuracies in an array and plot the decoding curves for both training and validation set. In these plots, add a line that denotes chance level.
#
# What do you observe? Does more data mean better classification? Did we already reach an optimal decoding accuracy, or can we still improve by adding more data?

# %%
"""Why are epoch iterables called 'p'? 
Especially whilst reading from a variable called 'P'? (which stands for 'Probability' or something?)

Epochs are ALSO named 's' in the shape tuple [k,s,n]...
Epochs aren't even the first dimension, so writing 'for p in P' doesn't even make sense in that way...

Please think about this for next time. Avoid:
* Referencing the same concept with multiple different names, or
* Referencing different concepts with the same name

"""

def decode_curve(P):
  Ks = []
  for k in range(P.shape[0]):
    for p in range(P.shape[1]):
      Ks.append(np.argmax(np.sum(P[k, :p], axis=0)))
  
  return np.array(Ks)

train_curve = decode_curve(p_train)

plt.plot(train_curve)
plt.show()

# %% [markdown]
# ### 4.7. Inspecting the classifier (0.5 points)<a class="anchor" id="classifier"></a>
# Many BCI research is focused around engineering a working system. By inspecting the system, we can maybe find ways to improve it, but it might also inform us about the information the BCI is using and provide us with valuable information for e.g. cognitive neuroscience.
#
# The LDA classifier we used here learned parameters for individual timepoints of Cz. This means the classifier learned a temporal filter. We can visualize this filter and loosly inspect what it finds important and what not. Remember that such filter does not tell us at what timepoint the discriminable information is, as some timepoints might be used only for noise cancellation (and by definition noise has no discriminable information).
#
# Plot the parameters learned by LDA. These are stored in `pipeline[1].coef_`.
#
# Do you see any patterns?

# %%
coef_df = train_pipeline[1].coef_
C = np.swapaxes(coef_df, 0, 1)

plt.plot(range(C.shape[0]), C)
plt.show()

# %% [markdown]
# # 5. Extension: Canonical Correlation Analysis<a class="anchor" id="extension"></a>

# %% [markdown]
# A next step to improve classification would be to use more and more channels by adding them in the feature selection process. Instead, we can predefine a spatial filter based on the knowledge that we have. With CCA we can utilize the fact that we are dealing with ERPs. Let's see how this works.

# %% [markdown]
# ### 5.1 The CCA (1.3 points)<a class="anchor" id="cca"></a>
# CCA is defined as follows:
# $$W_x, W_y = {\arg\max}_{W_x, W_y}\frac{W_x^\top X \cdot Y^\top W_y}{W_x\top X X^\top W_x \cdot W_y^\top Y Y^\top W_y}$$
# Specifically, CCA optimizes $W_x$ and $W_y$ such that the correlation between the projections $W_x^\top X$ and $W_y^\top Y$ is maximized. This is very convenient for use with ERPs. Let $X$ be the raw single-trials, and $Y$ be the averaged data (i.e., ERPs), then $W_x$ and $W_y$ become spatial filters that maximize the correlation between spatially filter EEG data and its ERP.
#
# Write a function `fit_cca(sX, sY)` that learns the spatial filters $W_x$ and $W_y$. First, vectorize the inputs, i.e., reshape `sX` to $X \in \mathbb{R}^{k*s,c,m}$ and `sY` to $Y \in \mathbb{R}^{k*s}$ -- note we take the last entry again which contains the target. Then, extract the target epochs and store them in a variable called `eeg`. From this variable, compute the erp by taking the average over epochs and store this in `erp`. Now, use `np.tile()` to repeat `erp` to the same shape as `eeg`. Both `eeg` and `erp` should have the same dimensions now. Permute and reshape both matrices to 2D matrices of shape $k*s \times c$. Finally, use `CCA()` from sklearn with n_components=1 and use `fit()` with `eeg` and `erp` as inputs to perform the CCA. The optimized $W_x$ and $W_y$ can be found in `cca.x_weights_` and `cca.y_weights`.
#
# Baically what we are doing here, is to match each single-trial with its ERP. Since we only have one ERP, this seems a bit odd, but essentially the CCA will optimze two spatial filters for us, so that each single-trial is made to resemble the ERP. The CCA does so by optimizing a spatial filter that boosts those channels that contain the signal, while optimally utilizing the other channels to reduce noise. Note, that the CCA optimizes a correlation. Multiplying both $W_x$ and $W_y$ with -1, i.e., changing its polarity, will not change the correlation. Hence, the CCA has freedom in choosing the polarity.
#
# Use the function to fit the spatial filters using the training data.

# %% [markdown]
# Next we want to apply the spatial filter $W_x$ to both the training and validation data to optimally combine the information in all channels. Write a function `apply_cca(sX, Wx)` that takes the multichannel data `sX`, and uses `Wx` to perform a weighted sum over channels. The output can be stored in `sfX`.
#
# Note, there is a very simple methematical operation that performs $\hat{X}=W_x^\top X$. Additionally, you either write a for loop over trials/epochs, or you temporarily reshape the data to a 2D matrix to perform this operation.
#
# Apply the function to both training and validation data to obtain `sfX_train` and `sfX_valid`.

# %%
# code here.

# %% [markdown]
# ### 5.2. Classifier calibration (0.2 points)<a class="anchor" id="calibration2"></a>
# As in the previous part, we need to calibrate a classifier. However, now we use the spatially filtered data, so we do not need to perform channel selection. Use your previously defined calibration function `calibrate()` but this time using the spatially filtered training data.

# %%
# code here.

# %% [markdown]
# ### 5.3. Epoch prediction (0.2 points)<a class="anchor" id="ep2"></a>
# Also in the epoch prediction, we can reuse the previously defined function, but this time inputting the spatially filtered data. Use your previously defined function `predict_epochs()` to predict the epoch probabilities using the spatially filtered data.

# %%
# code here.

# %% [markdown]
# ### 5.4. Epoch classification (0.2 points)<a class="anchor" id="ec2"></a>
# Also in the epoch classification, we can reuse the previously defined function. Use your previously defined function `classify_epochs()` to classify the epoch probabilities that were defined using the spatially filtered data.
#
# Can you already see an improvement?

# %%
# code here.

# %% [markdown]
# ### 5.5. Trial prediction (0.2 points)<a class="anchor" id="tp2"></a>
# Let's now use the previously defined `predict_trials()` function to convert to probabilities over different symbols. Make sure you use the spatially filtered data for both training and validation set.

# %%
# code here.

# %% [markdown]
# ### 5.6. Trial classification (0.2 points)<a class="anchor" id="tc2"></a>
# In a similar fashion, reuse `classify_trials()` to use the probabilities and accumulate evidence over epochs to form a decision on trial-level. Do this for both training and validation set and compute the classification accuracies.
#
# Did the classification improve?

# %%
# code here.

# %% [markdown]
# ### 5.7. Decoding curves (0.2 points)<a class="anchor" id="dc2"></a>
# Also for the CCA-based classifier, we can estimate decoding curves. Also here you can reuse your code from before. Plot the decoding curves for both training and validation set, and plot a line that denotes chance level.
#
# Do you see an improvement over the one-channel classifier?

# %%
# code here.

# %% [markdown]
# ### 5.8. Inspecting the classifier (0.5 points)<a class="anchor" id="classifier2"></a>
# Like before we can inspect the classifier to obtain insight in what the classifier learned. First, plot the temporal filter like previously. Second, use the `topoplot()` function with the `assignment1_channels.txt` layout file to plot the spatial filters $W_x$ and $W_y$.
#
# Can you interpret the temporal filter? Can you explain what the spatial filter shows? Could you argue why $W_x$ and $W_y$ are slightly different, and with that, why we use $W_x$ as spatial filter and not $W_y$?

# %%
# code here.
